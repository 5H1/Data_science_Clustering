# %%
##importing the data file

# %%
import pandas as pd
ds=pd.read_csv("EastWestAirlines.csv")
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
ds.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
ds.shape
# Out:
# (3999, 12)

# %%
ds.isnull()
# Out:
#         ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     False    False       False      False      False      False
# 1     False    False       False      False      False      False
# 2     False    False       False      False      False      False
# 3     False    False       False      False      False      False
# 4     False    False       False      False      False      False
# ...     ...      ...         ...        ...        ...        ...
# 3994  False    False       False      False      False      False
# 3995  False    False       False      False      False      False
# 3996  False    False       False      False      False      False
# 3997  False    False       False      False      False      False
# 3998  False    False       False      False      False      False
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0           False        False              False            False
# ...

# %%
ds.isnull()
# Out:
#         ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     False    False       False      False      False      False
# 1     False    False       False      False      False      False
# 2     False    False       False      False      False      False
# 3     False    False       False      False      False      False
# 4     False    False       False      False      False      False
# ...     ...      ...         ...        ...        ...        ...
# 3994  False    False       False      False      False      False
# 3995  False    False       False      False      False      False
# 3996  False    False       False      False      False      False
# 3997  False    False       False      False      False      False
# 3998  False    False       False      False      False      False
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0           False        False              False            False
# ...

# %%
##we caan observe there are no any null values.

# %%
##Data Preprocessing:
##1.Preprocess the dataset to handle missing values, remove outliers, and scale the features if necessary.
##2.Perform exploratory data analysis (EDA) to gain insights into the distribution of data and identify potential clusters.
##3.Use multiple visualizations to understand the hidden patterns in the dataset

# %%
#handle missing values
#since there are non null values there is no need to handle the missing values.

# %%
#handle missing values
#since there are non null values there is no need to handle the missing values.

# %%
#scaling the features will be done under data pre-processing.

# %%
##EDA

# %%
##STEP 2 BOXPLOTS
#step 2 a. performing Box plot on Balance column and observing outliers and inter quartile ranges
ds.boxplot(column='Balance',vert=False)

import numpy as np
q1 = np.percentile(ds["Balance"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["Balance"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(ds["Balance"][ds["Balance"] > UW]))
# Out:
# 25th percentile 18527.5
# 75th percentile 92404.0
# Inter quartile range: 73876.5
# Upper whisker length: 203218.75
# number of outliers greater than upper whisker: 266

# %%
##STEP 2 BOXPLOTS
#step 2 b. performing Box plot on Qual_miles column and observing outliers and inter quartile ranges
ds.boxplot(column='Qual_miles',vert=False)

import numpy as np
q1 = np.percentile(ds["Qual_miles"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["Qual_miles"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(ds["Qual_miles"][ds["Qual_miles"] > UW]))
# Out:
# 25th percentile 0.0
# 75th percentile 0.0
# Inter quartile range: 0.0
# Upper whisker length: 0.0
# number of outliers greater than upper whisker: 226

# %%
ds.boxplot(column='Qual_miles',vert=False)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["Qual_miles"]
# Creating plot
plt.boxplot(data)
 
# show plot
plt.show()

# %%
##STEP 2 BOXPLOTS
#step 2 c. performing Box plot on cc1_miles column and observing outliers and inter quartile ranges
ds.boxplot(column='cc1_miles',vert=False)

import numpy as np
q1 = np.percentile(ds["cc1_miles"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["cc1_miles"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(ds["cc1_miles"][ds["cc1_miles"] > UW]))
# Out:
# 25th percentile 1.0
# 75th percentile 3.0
# Inter quartile range: 2.0
# Upper whisker length: 6.0
# number of outliers greater than upper whisker: 0

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["cc1_miles"]
# Creating plot
plt.boxplot(data)
 
# show plot
plt.show()

# %%
##STEP 2 BOXPLOTS
#step 2 d. performing Box plot on cc2_miles column and observing outliers and inter quartile ranges
ds.boxplot(column='cc2_miles',vert=False)

import numpy as np
q1 = np.percentile(ds["cc2_miles"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["cc2_miles"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)

print("number of outliers greater than upper whisker:",len(ds["cc2_miles"][ds["cc2_miles"] > UW]))
# Out:
# 25th percentile 1.0
# 75th percentile 1.0
# Inter quartile range: 0.0
# Upper whisker length: 1.0
# number of outliers greater than upper whisker: 43

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["cc2_miles"]
# Creating plot
plt.boxplot(data)
 
# show plot
plt.show()

# %%
##STEP 2 BOXPLOTS
#step 2 e. performing Box plot on cc3_miles column and observing outliers and inter quartile ranges
ds.boxplot(column='cc3_miles',vert=False)

import numpy as np
q1 = np.percentile(ds["cc3_miles"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["cc3_miles"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)

print("number of outliers greater than upper whisker:",len(ds["cc3_miles"][ds["cc3_miles"] > UW]))
# Out:
# 25th percentile 1.0
# 75th percentile 1.0
# Inter quartile range: 0.0
# Upper whisker length: 1.0
# number of outliers greater than upper whisker: 18

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["cc3_miles"]
# Creating plot
plt.boxplot(data)
 
# show plot
plt.show()

# %%
##STEP 2 BOXPLOTS
#step 2 f. performing Box plot on Bonus_miles column and observing outliers and inter quartile ranges
ds.boxplot(column='Bonus_miles',vert=False)

import numpy as np
q1 = np.percentile(ds["Bonus_miles"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["Bonus_miles"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)

print("number of outliers greater than upper whisker:",len(ds["Bonus_miles"][ds["Bonus_miles"] > UW]))
# Out:
# 25th percentile 1250.0
# 75th percentile 23800.5
# Inter quartile range: 22550.5
# Upper whisker length: 57626.25
# number of outliers greater than upper whisker: 280

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["Bonus_miles"]
# Creating plot
plt.boxplot(data)
 
# show plot
plt.show()

# %%
##STEP 2 BOXPLOTS
#step 2 g. performing Box plot on Bonus_trans column and observing outliers and inter quartile ranges
ds.boxplot(column='Bonus_trans',vert=False)

import numpy as np
q1 = np.percentile(ds["Bonus_trans"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["Bonus_trans"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)

print("number of outliers greater than upper whisker:",len(ds["Bonus_trans"][ds["Bonus_trans"] > UW]))
# Out:
# 25th percentile 3.0
# 75th percentile 17.0
# Inter quartile range: 14.0
# Upper whisker length: 38.0
# number of outliers greater than upper whisker: 63

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["Bonus_trans"]
# Creating plot
plt.boxplot(data)
 
# show plot
plt.show()

# %%
##STEP 2 BOXPLOTS
#step 2 h. performing Box plot on Flight_miles_12mo column and observing outliers and inter quartile ranges
ds.boxplot(column='Flight_miles_12mo',vert=False)

import numpy as np
q1 = np.percentile(ds["Flight_miles_12mo"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["Flight_miles_12mo"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)

print("number of outliers greater than upper whisker:",len(ds["Flight_miles_12mo"][ds["Flight_miles_12mo"] > UW]))
# Out:
# 25th percentile 0.0
# 75th percentile 311.0
# Inter quartile range: 311.0
# Upper whisker length: 777.5
# number of outliers greater than upper whisker: 569

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["Flight_miles_12mo"]
# Creating plot
plt.boxplot(data)
 
# show plot
plt.show()

# %%
##STEP 2 BOXPLOTS
#step 2 i. performing Box plot on Flight_trans_12 column and observing outliers and inter quartile ranges
ds.boxplot(column='Flight_trans_12',vert=False)

import numpy as np
q1 = np.percentile(ds["Flight_trans_12"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["Flight_trans_12"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)

print("number of outliers greater than upper whisker:",len(ds["Flight_trans_12"][ds["Flight_trans_12"] > UW]))
# Out:
# 25th percentile 0.0
# 75th percentile 1.0
# Inter quartile range: 1.0
# Upper whisker length: 2.5
# number of outliers greater than upper whisker: 565

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["Flight_trans_12"]
# Creating plot
plt.boxplot(data,vert=False)
 
# show plot
plt.show()

# %%
##STEP 2 BOXPLOTS
#step 2 j. performing Box plot on Days_since_enroll column and observing outliers and inter quartile ranges
ds.boxplot(column='Days_since_enroll',vert=False)

import numpy as np
q1 = np.percentile(ds["Days_since_enroll"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["Days_since_enroll"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)

print("number of outliers greater than upper whisker length:",len(ds["Days_since_enroll"][ds["Days_since_enroll"] > UW]))
# Out:
# 25th percentile 2330.0
# 75th percentile 5790.5
# Inter quartile range: 3460.5
# Upper whisker length: 10981.25
# number of outliers greater than upper whisker length: 0

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["Days_since_enroll"]
# Creating plot
plt.boxplot(data,vert=False)
 
# show plot
plt.show()

# %%
##STEP 2 BOXPLOTS
#step 2 k. performing Box plot on Award? column and observing outliers and inter quartile ranges
ds.boxplot(column='Award?',vert=False)

import numpy as np
q1 = np.percentile(ds["Award?"],25)
print("25th percentile",q1)
q3 = np.percentile(ds["Award?"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)

print("number of outliers greater than upper whisker length:",len(ds["Award?"][ds["Award?"] > UW]))
# Out:
# 25th percentile 0.0
# 75th percentile 1.0
# Inter quartile range: 1.0
# Upper whisker length: 2.5
# number of outliers greater than upper whisker length: 0

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize =(10, 7))

data=ds["Award?"]
# Creating plot
plt.boxplot(data,vert=False)
 
# show plot
plt.show()

# %%
#HISTOGRAM
ds.hist("Balance")

print("Skewness of the Balance column:",ds['Balance'].skew())
print("Kurtosis of the Balance column ",ds['Balance'].kurt())
# Out:
# Skewness of the Balance column: 5.004187034431081
# Kurtosis of the Balance column  44.15793164623947

# %%
import matplotlib.pyplot as plt
plt.hist("Balance")
plt.show()

# %%
#histogram on qual_miles..

# %%
ds.hist("Qual_miles")
# Out:
# array([[<Axes: title={'center': 'Qual_miles'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.hist("Qual_miles")
plt.show()

# %%
print("skewness of the Qual_miles column is:",ds["Qual_miles"].skew())
# Out:
# skewness of the Qual_miles column is: 7.512395072097138

# %%
print("kurtosis of the Qual_miles column is:",ds["Qual_miles"].kurt())
# Out:
# kurtosis of the Qual_miles column is: 67.68935141908345

# %%
##cc1_miles..

# %%
import matplotlib.pyplot as plt
plt.hist("cc1_miles")
plt.show()

# %%
print("skewness of the cc1_miles column is:",ds["cc1_miles"].skew())
# Out:
# skewness of the cc1_miles column is: 0.8575689408978102

# %%
print("Kurtosis of the cc1_miles column is:",ds["cc1_miles"].kurt())
# Out:
# Kurtosis of the cc1_miles column is: -0.7485082995465442

# %%
ds.hist("cc2_miles")
# Out:
# array([[<Axes: title={'center': 'cc2_miles'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.hist("cc2_miles")
plt.show()

# %%
print("skewness of the cc2_miles column is:",ds["cc2_miles"].skew())
# Out:
# skewness of the cc2_miles column is: 11.210459211999869

# %%
print("Kurtosis of the cc2_miles column is:",ds["cc2_miles"].kurt())
# Out:
# Kurtosis of the cc2_miles column is: 133.78648931325637

# %%
ds.hist("cc3_miles")
# Out:
# array([[<Axes: title={'center': 'cc3_miles'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.hist("cc3_miles")
plt.show()

# %%
print("skewness of the cc3_miles column is:",ds["cc3_miles"].skew())
# Out:
# skewness of the cc3_miles column is: 17.195531943336444

# %%
print("Kurtosis of the cc3_miles column is:",ds["cc3_miles"].kurt())
# Out:
# Kurtosis of the cc3_miles column is: 308.6547278930168

# %%
#Bonus_miles
ds.hist("Bonus_miles")
# Out:
# array([[<Axes: title={'center': 'Bonus_miles'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.hist("Bonus_miles")
plt.show()

# %%
print("skewness of the Bonus_miles column is:",ds["Bonus_miles"].skew())
# Out:
# skewness of the Bonus_miles column is: 2.8420933668869197

# %%
print("Kurtosis of the Bonus_miles column is:",ds["Bonus_miles"].kurt())
# Out:
# Kurtosis of the Bonus_miles column is: 13.630489238331991

# %%
#Bonus_trans
ds.hist("Bonus_trans")
# Out:
# array([[<Axes: title={'center': 'Bonus_trans'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.hist("Bonus_trans")
plt.show()

# %%
print("skewness of the Bonus_trans column is:",ds["Bonus_trans"].skew())
# Out:
# skewness of the Bonus_trans column is: 1.1573624831608498

# %%
print("Kurtosis of the Bonus_trans column is:",ds["Bonus_trans"].kurt())
# Out:
# Kurtosis of the Bonus_trans column is: 2.7457371278773044

# %%
#Flight_miles_12mo
ds.hist("Flight_miles_12mo")
# Out:
# array([[<Axes: title={'center': 'Flight_miles_12mo'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.hist("Flight_miles_12mo")
plt.show()

# %%
print("skewness of the Flight_miles_12mo column is:",ds["Flight_miles_12mo"].skew())
# Out:
# skewness of the Flight_miles_12mo column is: 7.451666167619329

# %%
print("Kurtosis of the Flight_miles_12mo column is:",ds["Flight_miles_12mo"].kurt())
# Out:
# Kurtosis of the Flight_miles_12mo column is: 94.76101871527655

# %%
#Flight_trans_12
ds.hist("Flight_trans_12")
# Out:
# array([[<Axes: title={'center': 'Flight_trans_12'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.hist("Flight_trans_12")
plt.show()

# %%
print("skewness of the Flight_trans_12 column is:",ds["Flight_trans_12"].skew())
# Out:
# skewness of the Flight_trans_12 column is: 5.490461246535664

# %%
print("Kurtosis of the Flight_trans_12 column is:",ds["Flight_trans_12"].kurt())
# Out:
# Kurtosis of the Flight_trans_12 column is: 42.978152375989566

# %%
#Days_since_enroll
ds.hist("Days_since_enroll")
# Out:
# array([[<Axes: title={'center': 'Days_since_enroll'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.hist("Days_since_enroll")
plt.show()

# %%
print("skewness of the Days_since_enroll column is:",ds["Days_since_enroll"].skew())
# Out:
# skewness of the Days_since_enroll column is: 0.12017356507902774

# %%
print("Kurtosis of the Days_since_enroll column is:",ds["Days_since_enroll"].kurt())
# Out:
# Kurtosis of the Days_since_enroll column is: -0.9675053776216838

# %%
#award
ds["Award?"].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.hist("Award?")
plt.show()

# %%
print("skewness of the Award? column is:",ds["Award?"].skew())
# Out:
# skewness of the Award? column is: 0.5372003821474526

# %%
print("Kurtosis of the Award? column is:",ds["Award?"].kurt())
# Out:
# Kurtosis of the Award? column is: -1.7122723499779504

# %%
##DENSITY PLOTS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['Balance'], shade=True)
plt.title('Density Plot of Balance')
plt.xlabel('Balance')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\4190400654.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Balance'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['Qual_miles'], shade=True)
plt.title('Density Plot of Qual_miles')
plt.xlabel('Qual_miles')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\1870535550.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Qual_miles'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['Qual_miles'], shade=True)
plt.title('Density Plot of Qual_miles')
plt.xlabel('Qual_miles')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\1870535550.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Qual_miles'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['cc1_miles'], shade=True)
plt.title('Density Plot of cc1_miles')
plt.xlabel('cc1_miles')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\2911469673.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['cc1_miles'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['cc2_miles'], shade=True)
plt.title('Density Plot of cc2_miles')
plt.xlabel('cc2_miles')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\2744829801.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['cc2_miles'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['cc3_miles'], shade=True)
plt.title('Density Plot of cc3_miles')
plt.xlabel('cc3_miles')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\1539999429.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['cc3_miles'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Bonus_miles

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['Bonus_miles'], shade=True)
plt.title('Density Plot of Bonus_miles')
plt.xlabel('Bonus_miles')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\2627186835.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Bonus_miles'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['Bonus_trans'], shade=True)
plt.title('Density Plot of Bonus_trans')
plt.xlabel('Bonus_trans')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\4041255511.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Bonus_trans'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#FLight_miles_12mo

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['Flight_miles_12mo'], shade=True)
plt.title('Density Plot of Flight_miles_12mo')
plt.xlabel('Flight_miles_12mo')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\1010512665.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Flight_miles_12mo'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['Flight_trans_12'], shade=True)
plt.title('Density Plot of Flight_trans_12')
plt.xlabel('Flight_trans_12')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\1503443718.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Flight_trans_12'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['Days_since_enroll'], shade=True)
plt.title('Density Plot of Days_since_enroll')
plt.xlabel('Days_since_enroll')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\2065911831.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Days_since_enroll'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("EastWestAirlines.csv")
# Plotting density plot
sns.kdeplot(wdata['Award?'], shade=True)
plt.title('Density Plot of Award?')
plt.xlabel('Award?')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\1375852074.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Award?'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#3.Use multiple visualizations to understand the hidden patterns in the dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv("EastWestAirlines.csv")

# Compute the correlation matrix
correlation_matrix = data.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Add title and labels for better understanding
plt.title('Correlation Heatmap of Wine Dataset')
plt.show()

# %%
#correlations

# %%
ds.corr()
# Out:
#                         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# ID#                1.000000 -0.243737   -0.019374  -0.224465   0.020291
# Balance           -0.243737  1.000000    0.108722   0.338344  -0.008804
# Qual_miles        -0.019374  0.108722    1.000000   0.007931  -0.013923
# cc1_miles         -0.224465  0.338344    0.007931   1.000000  -0.068223
# cc2_miles          0.020291 -0.008804   -0.013923  -0.068223   1.000000
# cc3_miles         -0.014707  0.035243   -0.007779   0.060555  -0.006166
# Bonus_miles       -0.203012  0.403487    0.031021   0.825200  -0.003969
# Bonus_trans       -0.146915  0.324935    0.050725   0.608943   0.064399
# Flight_miles_12mo -0.031013  0.217551    0.126774   0.037370   0.010598
# Flight_trans_12   -0.052096  0.255700    0.144004   0.041333   0.028284
# Days_since_enroll -0.964988  0.263129    0.017312   0.230849  -0.005807
# Award?            -0.177901  0.178494    0.095256   0.335457   0.005332
#
# ...

# %%
#Implementing Clustering Algorithms:

#Implement the K-Means, hierarchical, and DBSCAN algorithms using a programming language such as Python with libraries like scikit-learn or MATLAB.

#Apply each clustering algorithm to the pre-processed dataset to identify clusters within the data.

#Experiment with different parameter settings for hierarchical clustering (e.g., linkage criteria),
#K-means (Elbow curve for different K values) and DBSCAN (e.g., epsilon, minPts) and evaluate the clustering results.

# %%
#IMPLEMENTING CLUSTERING ALGORTIHMS

# %%
df=pd.read_csv("EastWEstAirlines.csv")
#Declaring X and Y variable
X = df.iloc[:,1:]

# %%
X
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
##THE DATA WHICH IS WITHOUT ID COLUMN IS SHOWN AS X

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)
SS_X = pd.DataFrame(SS_X)
SS_X.columns = list(X)

SS_X.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4  0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0    -1.104065          -0.328603        -0.362168           1.395454
# 1    -0.999926          -0.328603        -0.362168           1.379957
# 2    -0.791649          -0.328603        -0.362168           1.411920
# 3    -1.104065          -0.328603        -0.362168           1.372208
# 4     1.499394           1.154932         0.692490           1.363975
#
#      Award?
# 0 -0.766919
# 1 -0.766919
# 2 -0.766919
# 3 -0.766919
# 4  1.303918

# %%
#implementing agglomerative clustering

# %%
#DIFFERENT CLUSTERS NUMBERS WITH SINGLE LINKAGE METHOD

# %%
##single linkage method
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=5,linkage='single')

df["Agg"] = cluster.fit_predict(SS_X)

df

Y = df["Agg"]

df["Agg"].value_counts()

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.5378591358408883

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
##single linkage method
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3,linkage='single')

df["Agg"] = cluster.fit_predict(SS_X)

df

Y = df["Agg"]

df["Agg"].value_counts()

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.7350532148998382

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
##single linkage method
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2,linkage='single')

df["Agg"] = cluster.fit_predict(SS_X)

df

Y = df["Agg"]

df["Agg"].value_counts()

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.8562820070415407

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
##single linkage method
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=6,linkage='single')

df["Agg"] = cluster.fit_predict(SS_X)

df

Y = df["Agg"]

df["Agg"].value_counts()

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.5364116456429503

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
scores = []

for i in range(2,10):
    cluster = AgglomerativeClustering(n_clusters=i,linkage='single')
    X["Agg"] = cluster.fit_predict(SS_X)
    Y = X["Agg"]
    scores.append(silhouette_score(SS_X,Y))
    
    
import matplotlib.pyplot as plt
plt.scatter(range(2,10),scores)
plt.plot(range(2,10),scores,color='red')
plt.xlabel("cluster numbers")   
plt.ylabel("silhoutte scores")
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\2965494413.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Agg"] = cluster.fit_predict(SS_X)
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\2965494413.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Agg"] = cluster.fit_predict(SS_X)
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\2965494413.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
scores = []

for i in range(2,10):
    cluster = AgglomerativeClustering(n_clusters=i,linkage='average')
    X["Agg"] = cluster.fit_predict(SS_X)
    Y = X["Agg"]
    scores.append(silhouette_score(SS_X,Y))
    
    
import matplotlib.pyplot as plt
plt.scatter(range(2,10),scores)
plt.plot(range(2,10),scores,color='red')
plt.xlabel("cluster numbers")   
plt.ylabel("silhoutte scores")
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\357911675.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Agg"] = cluster.fit_predict(SS_X)
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\357911675.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Agg"] = cluster.fit_predict(SS_X)
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\357911675.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
scores = []

for i in range(2,10):
    cluster = AgglomerativeClustering(n_clusters=i,linkage='ward')
    X["Agg"] = cluster.fit_predict(SS_X)
    Y = X["Agg"]
    scores.append(silhouette_score(SS_X,Y))
    
    
import matplotlib.pyplot as plt
plt.scatter(range(2,10),scores)
plt.plot(range(2,10),scores,color='red')
plt.xlabel("cluster numbers")   
plt.ylabel("silhoutte scores")
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\221800302.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Agg"] = cluster.fit_predict(SS_X)
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\221800302.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Agg"] = cluster.fit_predict(SS_X)
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\221800302.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
scores = []

for i in range(2,10):
    cluster = AgglomerativeClustering(n_clusters=i,linkage='complete')
    X["Agg"] = cluster.fit_predict(SS_X)
    Y = X["Agg"]
    scores.append(silhouette_score(SS_X,Y))
    
    
import matplotlib.pyplot as plt
plt.scatter(range(2,10),scores)
plt.plot(range(2,10),scores,color='red')
plt.xlabel("cluster numbers")   
plt.ylabel("silhoutte scores")
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\1518296916.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Agg"] = cluster.fit_predict(SS_X)
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\1518296916.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Agg"] = cluster.fit_predict(SS_X)
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_9420\1518296916.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#DIFFERENT CLUSTERS NUMBERS WITH AVERAGE LINKAGE METHOD

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=5,linkage='average')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.7700180807329777

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=4,linkage='average')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.7731120442583631

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3,linkage='average')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.7838667595062349

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2,linkage='average')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.8111134025692677

# %%
#DIFFERENT CLUSTERS NUMBERS WITH WARD LINKAGE METHOD

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=5,linkage='ward')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.3098805307874414

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=4,linkage='ward')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.30814152852022786

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3,linkage='ward')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.2940432062008608

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2,linkage='ward')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.28926595242577247

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
#DIFFERENT CLUSTERS NUMBERS WITH COMPLETED LINKAGE METHOD

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=5,linkage='complete')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.5625737661941762

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=4,linkage='complete')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.5985727763092806

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3,linkage='complete')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.7760836053602842

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2,linkage='complete')
df["Agg"] = cluster.fit_predict(SS_X)
Y = df["Agg"]

plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  

from sklearn.metrics import silhouette_score
silhouette_score(SS_X,Y)
# Out:
# 0.8111134025692677

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,1], c=cluster.labels_, cmap='rainbow')  
plt.show()

# %%
##from the complete linkage method we got the highest cluster number as 2.

# %%
from scipy.cluster.hierarchy import fcluster

# Using 'ward' linkage as an example
Z = linkage(SS_X, method='ward')
hierarchical_labels = fcluster(Z, t=optimal_clusters, criterion='maxclust')
silhouette_hierarchical = silhouette_score(SS_X, hierarchical_labels)
print(f'Silhouette Score for Hierarchical Clustering: {silhouette_hierarchical}')
# Out:
# Silhouette Score for Hierarchical Clustering: 0.28926595242577247

# %%
from scipy.cluster.hierarchy import fcluster

# Using 'ward' linkage as an example
Z = linkage(SS_X, method='complete')
hierarchical_labels = fcluster(Z, t=optimal_clusters, criterion='maxclust')
silhouette_hierarchical = silhouette_score(SS_X, hierarchical_labels)
print(f'Silhouette Score for Hierarchical Clustering: {silhouette_hierarchical}')
# Out:
# Silhouette Score for Hierarchical Clustering: 0.8111134025692677

# %%
from scipy.cluster.hierarchy import fcluster

# Using 'ward' linkage as an example
Z = linkage(SS_X, method='ward')
hierarchical_labels = fcluster(Z, t=optimal_clusters, criterion='maxclust')
silhouette_hierarchical = silhouette_score(SS_X, hierarchical_labels)
print(f'Silhouette Score for Hierarchical Clustering: {silhouette_hierarchical}')
# Out:
# Silhouette Score for Hierarchical Clustering: 0.28926595242577247

# %%
#PERFORMING DENDROGRAM

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load the dataset

data1 = pd.read_csv('EastWestAirlines.csv')

# Separating out the features (excluding the target column if present)
#features = data.drop('target', axis=1)  # Assuming 'target' is the name of the target column

# Standardizing the features
#scaler = StandardScaler()
#features_standardized = scaler.fit_transform(features)

# Compute the distance matrix and perform hierarchical clustering
linked = linkage(SS_X, method='ward')

# Plot the dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked,
           orientation='top',
           distance_sort='descending',
           show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load the dataset

data1 = pd.read_csv('EastWestAirlines.csv')

# Separating out the features (excluding the target column if present)
#features = data.drop('target', axis=1)  # Assuming 'target' is the name of the target column

# Standardizing the features
#scaler = StandardScaler()
#features_standardized = scaler.fit_transform(features)

# Compute the distance matrix and perform hierarchical clustering
linked = linkage(SS_X, method='single')

# Plot the dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked,
           orientation='top',
           distance_sort='descending',
           show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

data12=pd.read_csv("EastWestAirlines.csv")

data_features = data12.drop('ID#', axis=1)

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_features)

# Create the dendrogram
plt.figure(figsize=(10, 7))
dendrogram = sch.dendrogram(sch.linkage(scaled_data, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Euclidean distances')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram

from sklearn.cluster import AgglomerativeClustering


def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)


#iris = load_iris()
#X = iris.data
import pandas as pd
ds=pd.read_csv("EastWestAirlines.csv")
X=ds.iloc[:,1:]
# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

model = model.fit(X)
plt.title("Hierarchical Clustering Dendrogram")
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode="level", p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %%
#2ND METHOD LET US IMPLEMENT KMEANS

# %%
##implementing k-means

# %%
#==================================================================
# K - means clustering
#==================================================================

import pandas as pd
df = pd.read_csv("EastWestAirlines.csv")
df

X = df.iloc[:, 1:]
    
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6,n_init=20)

df["kmeans"] = kmeans.fit_predict(SS_X)
df["kmeans"].value_counts()
# Out:
# kmeans
# 1    2077
# 3     908
# 0     822
# 4     134
# 5      43
# 2      15
# Name: count, dtype: int64

# %%
#==================================================================
# K - means clustering
#==================================================================

#import pandas as pd
#df = pd.read_csv("EastWestAirlines.csv")
#df

#X = df.iloc[:, 1:]
    
#from sklearn.preprocessing import StandardScaler
#SS = StandardScaler()
#SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6,n_init=20)

df["kmeans"] = kmeans.fit_predict(SS_X)
df["kmeans"].value_counts()
# Out:
# kmeans
# 1    2484
# 0    1253
# 2     143
# 3      61
# 5      43
# 4      15
# Name: count, dtype: int64

# %%
#==================================================================
# K - means clustering
#==================================================================

#import pandas as pd
#df = pd.read_csv("EastWestAirlines.csv")
#df

#X = df.iloc[:, 1:]
    
#from sklearn.preprocessing import StandardScaler
#SS = StandardScaler()
#SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5,n_init=2)

df["kmeans"] = kmeans.fit_predict(SS_X)
df["kmeans"].value_counts()
# Out:
# kmeans
# 4    1723
# 2     861
# 1     717
# 0     565
# 3     133
# Name: count, dtype: int64

# %%
#==================================================================
# K - means clustering
#==================================================================

#import pandas as pd
#df = pd.read_csv("EastWestAirlines.csv")
#df

#X = df.iloc[:, 1:]
    
#from sklearn.preprocessing import StandardScaler
#SS = StandardScaler()
#SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4,n_init=12)

df["kmeans"] = kmeans.fit_predict(SS_X)
df["kmeans"].value_counts()
# Out:
# kmeans
# 1    2562
# 2    1262
# 0     160
# 3      15
# Name: count, dtype: int64

# %%
#==================================================================
# K - means clustering
#==================================================================

#import pandas as pd
#df = pd.read_csv("EastWestAirlines.csv")
#df

#X = df.iloc[:, 1:]
    
#from sklearn.preprocessing import StandardScaler
#SS = StandardScaler()
#SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,n_init=10)

df["kmeans"] = kmeans.fit_predict(SS_X)
df["kmeans"].value_counts()
# Out:
# kmeans
# 1    2574
# 0    1261
# 2     164
# Name: count, dtype: int64

# %%
#==================================================================
# K - means clustering
#==================================================================

#import pandas as pd
#df = pd.read_csv("EastWestAirlines.csv")
#df

#X = df.iloc[:, 1:]
    
#from sklearn.preprocessing import StandardScaler
#SS = StandardScaler()
#SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2,n_init=4)

df["kmeans"] = kmeans.fit_predict(SS_X)
df["kmeans"].value_counts()
# Out:
# kmeans
# 0    2697
# 1    1302
# Name: count, dtype: int64

# %%
#==================================================================
# K - means clustering
#==================================================================

#import pandas as pd
#df = pd.read_csv("EastWestAirlines.csv")
#df

#X = df.iloc[:, 1:]
    
#from sklearn.preprocessing import StandardScaler
#SS = StandardScaler()
#SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2,n_init=5)

df["kmeans"] = kmeans.fit_predict(SS_X)
df["kmeans"].value_counts()
# Out:
# kmeans
# 1    2706
# 0    1293
# Name: count, dtype: int64

# %%
#performed elobe method for identifying number of k best clusters.

# %%
from sklearn.cluster import KMeans
clust = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i,random_state=0,n_init=1)
    kmeans.fit(SS_X)
    clust.append(kmeans.inertia_)
    
clust
# Out:
# [35409.61927448695,
#  30900.764032256797,
#  28912.774775220838,
#  26319.99552713807,
#  22895.347852022125,
#  21520.562468975735,
#  18191.09732684923,
#  16536.246392655277,
#  15066.809438840493]

# %%
#==============================================================
from sklearn.metrics import silhouette_score

scores = []

for i in range(2,10):
    cluster = KMeans(n_clusters=i,n_init=20)
    df["kmeans"] = cluster.fit_predict(SS_X)
    Y = df["kmeans"]
    scores.append(silhouette_score(SS_X,Y))
    
    
import matplotlib.pyplot as plt
plt.scatter(range(2,10),scores)
plt.plot(range(2,10),scores,color='red')
plt.xlabel("cluster numbers")   
plt.ylabel("silhoutte scores")
plt.show()

# %%
print(scores)
# Out:
# [0.32542136327826215, 0.31120106054803415, 0.30994920555619637, 0.32433823191955125, 0.28682271367849543, 0.2837314182984859, 0.23680303467419028, 0.245863692710433]

# %%
#for kmeans we can obsrve there is highest silhouette score for k=2.

# %%
from sklearn.metrics import silhouette_score

# Optimal number of clusters from Elbow method
optimal_clusters = 3  # Example, replace with the actual optimal number from the Elbow method

kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
kmeans_labels = kmeans.fit_predict(SS_X)
silhouette_kmeans = silhouette_score(SS_X, kmeans_labels)
print(f'Silhouette Score for K-Means: {silhouette_kmeans}')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Silhouette Score for K-Means: 0.31120106054803415

# %%
from sklearn.metrics import silhouette_score

# Optimal number of clusters from Elbow method
optimal_clusters = 2  # Example, replace with the actual optimal number from the Elbow method

kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
kmeans_labels = kmeans.fit_predict(SS_X)
silhouette_kmeans = silhouette_score(SS_X, kmeans_labels)
print(f'Silhouette Score for K-Means: {silhouette_kmeans}')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Silhouette Score for K-Means: 0.32542136327826215

# %%
#DBSCAN IMPLEMENTATION.

# %%
#==============================================================
# DBSCAN --> density based spatial clustering with applications of noise
#==============================================================

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.75,min_samples=3)

dbscan.fit(SS_X)
dbscan.labels_
df['dbscan']  = dbscan.labels_
df['dbscan'].value_counts()

df_final = df[df['dbscan'] != -1]
df_final.shape


#=================================================================
# Out:
# (3258, 14)

# %%
df_final.shape
# Out:
# (3258, 14)

# %%
#==============================================================
# DBSCAN --> density based spatial clustering with applications of noise
#==============================================================

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.51,min_samples=3)

dbscan.fit(SS_X)
dbscan.labels_
df['dbscan']  = dbscan.labels_
df['dbscan'].value_counts()

df_final = df[df['dbscan'] != -1]
df_final.shape


#=================================================================
# Out:
# (2805, 14)

# %%
#==============================================================
# DBSCAN --> density based spatial clustering with applications of noise
#==============================================================

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.5,min_samples=3)

dbscan.fit(SS_X)
dbscan.labels_
df['dbscan']  = dbscan.labels_
df['dbscan'].value_counts()

df_final = df[df['dbscan'] != -1]
df_final.shape


#=================================================================
# Out:
# (2771, 14)

# %%
#==============================================================
# DBSCAN --> density based spatial clustering with applications of noise
#==============================================================

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.5,min_samples=2)

dbscan.fit(SS_X)
dbscan.labels_
df['dbscan']  = dbscan.labels_
df['dbscan'].value_counts()

df_final = df[df['dbscan'] != -1]
df_final.shape


#=================================================================
# Out:
# (2915, 14)

# %%
#==============================================================
# DBSCAN --> density based spatial clustering with applications of noise
#==============================================================

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.25,min_samples=2)

dbscan.fit(SS_X)
dbscan.labels_
df['dbscan']  = dbscan.labels_
df['dbscan'].value_counts()

df_final = df[df['dbscan'] != -1]
df_final.shape


#=================================================================
# Out:
# (1860, 14)

# %%
#==============================================================
# DBSCAN --> density based spatial clustering with applications of noise
#==============================================================

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.25,min_samples=3)

dbscan.fit(SS_X)
dbscan.labels_
df['dbscan']  = dbscan.labels_
df['dbscan'].value_counts()

df_final = df[df['dbscan'] != -1]
df_final.shape


#=================================================================
# Out:
# (1604, 14)

# %%
#==============================================================
# DBSCAN --> density based spatial clustering with applications of noise
#==============================================================

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.15,min_samples=4)

dbscan.fit(SS_X)
dbscan.labels_
df['dbscan']  = dbscan.labels_
df['dbscan'].value_counts()

df_final = df[df['dbscan'] != -1]
df_final.shape


#=================================================================
# Out:
# (861, 14)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("EastWestAirlines.csv")
# Create a subset of the data for visualization
viz_features = ['Balance', 'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo']
data_viz = data[viz_features]

# Pair plot to visualize clusters
sns.pairplot(data_viz, palette='tab10')
plt.suptitle("DBSCAN Clustering", y=1.02)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("EastWestAirlines.csv")
# Create a subset of the data for visualization
viz_features = ['Balance', 'Bonus_miles', 'Bonus_trans','cc1_miles','cc2_miles','cc3_miles', 'Flight_miles_12mo','Flight_trans_12',"Days_since_enroll","Award?"]
data_viz = data[viz_features]

# Pair plot to visualize clusters
sns.pairplot(data_viz, palette='tab10')
plt.suptitle("DBSCAN Clustering", y=1.02)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#BSCAN (e.g., epsilon, minPts) and evaluate the clustering results.

# %%
eps = 0.5
min_samples = 5

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.14397923390835202

# %%
eps = 0.6
min_samples = 5

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.15894501798190097

# %%
eps = 0.7
min_samples =6

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.15843022299659001

# %%
eps = 0.8
min_samples =5

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.22748003209128073

# %%
eps = 0.9
min_samples =5

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.3013752626819816

# %%
eps = 0.9
min_samples =4

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.015897242025957242

# %%
eps = 0.9
min_samples =10

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.3224351108751572

# %%
eps = 0.9
min_samples =15

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.325937904295121

# %%
eps = 0.9
min_samples =38

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.3431969985821804

# %%
eps = 0.9
min_samples =40

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.3450865218167675

# %%
eps = 0.9
min_samples =50
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.3498406682227961

# %%
eps = 0.9
min_samples =47
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.3481628284256039

# %%
eps = 0.9
min_samples =58
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.3561360508764789

# %%
eps = 0.9
min_samples =60
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.3588652750063427

# %%
##FOR EPSILON=0.9 AND MIN SAMPLES = 60 WE GOT THE HIGHEST VALUES FOR SILHOUETTE SCORE AS 0.359

# %%
eps = 0.9
min_samples =64
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.31371753817819603

# %%
eps = 0.9
min_samples =79
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.31415673831038365

# %%
eps = 0.9
min_samples =72
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.32417129378519155

# %%
#we can observe there is a good increase in silhouette score for epsilon=0.9.

# %%
eps = 0.14
min_samples = 5

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: -0.33570321500003625

# %%
eps = 0.5
min_samples = 4

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: 0.10841009318338253

# %%
eps = 0.25
min_samples = 3

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: -0.2887614872630902

# %%
eps = 0.75
min_samples = 3

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: -0.05119837815035809

# %%
eps = 0.75
min_samples = 2

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan_labels = dbscan.fit_predict(SS_X)
# Filter out noise points for silhouette score calculation
core_samples_mask = dbscan_labels != -1
silhouette_dbscan = silhouette_score(SS_X[core_samples_mask], dbscan_labels[core_samples_mask])
print(f'Silhouette Score for DBSCAN: {silhouette_dbscan}')
# Out:
# Silhouette Score for DBSCAN: -0.22508790381145857

# %%
###Plot the clusters with different colours to visualize the separation of data points belonging to different clusters.
###Visualize the clustering results using scatter plots or other suitable visualization techniques.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Excel file
#file_path = 'EastWestAirlines.xlsx'
#data = pd.read_excel(file_path, sheet_name='data')
import pandas as pd
data=pd.read_csv("EastWestAirlines.csv")


# Select relevant columns for clustering
features = ['Balance', 'Qual_miles','cc1_miles','cc2_miles','cc3_miles','Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12', 'Days_since_enroll']
data_selected = data[features]

# Standardize the features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_selected)

# Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(data_scaled)

# Add cluster labels to the original data
data['Cluster'] = clusters
print(data['Cluster'].value_counts())

# Create a subset of the data for visualization
viz_features = ['Balance', 'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Cluster']
data_viz = data[viz_features]

# Pair plot to visualize clusters
sns.pairplot(data_viz, hue='Cluster', palette='tab10')
plt.suptitle("DBSCAN Clustering", y=1.02)
plt.show()
# Out:
# Cluster
#  0     1796
# -1     1229
#  5      436
#  4      272
#  1      177
#  2       40
#  9       10
#  3        7
#  10       7
#  12       6
#  6        5
#  7        5
#  11       5
#  8        4
# Name: count, dtype: int64
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Excel file
#file_path = 'EastWestAirlines.xlsx'
#data = pd.read_excel(file_path, sheet_name='data')
import pandas as pd
data=pd.read_csv("EastWestAirlines.csv")


# Select relevant columns for clustering
features = ['Balance', 'Qual_miles','cc1_miles','cc2_miles','cc3_miles','Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12', 'Days_since_enroll']
data_selected = data[features]

# Standardize the features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_selected)

# Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(data_scaled)

# Add cluster labels to the original data
data['Cluster'] = clusters
print(data['Cluster'].value_counts())

# Create a subset of the data for visualization
viz_features = ['Flight_miles_12mo','Flight_trans_12','Days_since_enroll','Cluster']
data_viz = data[viz_features]

# Pair plot to visualize clusters
sns.pairplot(data_viz, hue='Cluster', palette='tab10')
plt.suptitle("DBSCAN Clustering", y=1.02)
plt.show()
# Out:
# Cluster
#  0     1796
# -1     1229
#  5      436
#  4      272
#  1      177
#  2       40
#  9       10
#  3        7
#  10       7
#  12       6
#  6        5
#  7        5
#  11       5
#  8        4
# Name: count, dtype: int64
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import numpy as np
import matplotlib.pyplot as plt

# Load the Excel file
#data = pd.read_excel(file_path, sheet_name='data')
import pandas as pd
data=pd.read_csv("EastWestAirlines.csv")
# Select relevant columns for clustering
features = ['Balance', 'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12', 'Days_since_enroll']
data_selected = data[features]

# Standardize the features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_selected)

# Compute the k-distance graph
k = 4  # Typically, min_samples is used as k
neighbors = NearestNeighbors(n_neighbors=k)
neighbors_fit = neighbors.fit(data_scaled)
distances, indices = neighbors_fit.kneighbors(data_scaled)

# Sort the distances (4th column) in ascending order
distances = np.sort(distances[:, k-1])

# Plot the distances
plt.plot(distances)
plt.ylabel('k-distance')
plt.xlabel('Points sorted by distance')
plt.title('k-distance Graph')
plt.show()

# Set the chosen eps value (based on the k-distance graph)
eps_value = 0.5  # Replace with the chosen value from the k-distance graph

# Apply DBSCAN
dbscan = DBSCAN(eps=eps_value, min_samples=4)
clusters = dbscan.fit_predict(data_scaled)

# Add cluster labels to the original data
data['Cluster'] = clusters
print(data['Cluster'].value_counts())

# Create a subset of the data for visualization
viz_features = ['Balance', 'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Cluster']
data_viz = data[viz_features]

# Pair plot to visualize clusters
sns.pairplot(data_viz, hue='Cluster', palette='tab10')
plt.suptitle("DBSCAN Clustering", y=1.02)
plt.show()
# Out:
# Cluster
#  0    3085
# -1     881
#  3       9
#  7       5
#  1       4
#  2       4
#  5       4
#  6       4
#  4       3
# Name: count, dtype: int64
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import numpy as np
import matplotlib.pyplot as plt

# Load the Excel file
#data = pd.read_excel(file_path, sheet_name='data')
import pandas as pd
data=pd.read_csv("EastWestAirlines.csv")
# Select relevant columns for clustering
features = ['Balance', 'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12', 'Days_since_enroll']
data_selected = data[features]

# Standardize the features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_selected)

# Compute the k-distance graph
k = 4  # Typically, min_samples is used as k
neighbors = NearestNeighbors(n_neighbors=k)
neighbors_fit = neighbors.fit(data_scaled)
distances, indices = neighbors_fit.kneighbors(data_scaled)

# Sort the distances (4th column) in ascending order
distances = np.sort(distances[:, k-1])

# Plot the distances
plt.plot(distances)
plt.ylabel('k-distance')
plt.xlabel('Points sorted by distance')
plt.title('k-distance Graph')
plt.show()

# Set the chosen eps value (based on the k-distance graph)
eps_value = 0.5  # Replace with the chosen value from the k-distance graph

# Apply DBSCAN
dbscan = DBSCAN(eps=eps_value, min_samples=4)
clusters = dbscan.fit_predict(data_scaled)

# Add cluster labels to the original data
data['Cluster'] = clusters
print(data['Cluster'].value_counts())

# Create a subset of the data for visualization
viz_features = ['Flight_trans_12','Days_since_enroll', 'Cluster']
data_viz = data[viz_features]

# Pair plot to visualize clusters
sns.pairplot(data_viz, hue='Cluster', palette='tab10')
plt.suptitle("DBSCAN Clustering", y=1.02)
plt.show()
# Out:
# Cluster
#  0    3085
# -1     881
#  3       9
#  7       5
#  1       4
#  2       4
#  5       4
#  6       4
#  4       3
# Name: count, dtype: int64
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import numpy as np
import matplotlib.pyplot as plt

# Load the Excel file
#data = pd.read_excel(file_path, sheet_name='data')
import pandas as pd
data=pd.read_csv("EastWestAirlines.csv")
# Select relevant columns for clustering
features = ['Balance', 'Bonus_miles', 'Bonus_trans','Qual_miles','cc1_miles','cc2_miles','cc3_miles', 'Flight_miles_12mo', 'Flight_trans_12', 'Days_since_enroll']
data_selected = data[features]

# Standardize the features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_selected)

# Compute the k-distance graph
k = 4  # Typically, min_samples is used as k
neighbors = NearestNeighbors(n_neighbors=k)
neighbors_fit = neighbors.fit(data_scaled)
distances, indices = neighbors_fit.kneighbors(data_scaled)

# Sort the distances (4th column) in ascending order
distances = np.sort(distances[:, k-1])

# Plot the distances
plt.plot(distances)
plt.ylabel('k-distance')
plt.xlabel('Points sorted by distance')
plt.title('k-distance Graph')
plt.show()

# Set the chosen eps value (based on the k-distance graph)
eps_value = 0.5  # Replace with the chosen value from the k-distance graph

# Apply DBSCAN
dbscan = DBSCAN(eps=eps_value, min_samples=4)
clusters = dbscan.fit_predict(data_scaled)

# Add cluster labels to the original data
data['Cluster'] = clusters
print(data['Cluster'].value_counts())

# Create a subset of the data for visualization
viz_features = ['Qual_miles','cc1_miles','cc2_miles','cc3_miles', 'Cluster']
data_viz = data[viz_features]

# Pair plot to visualize clusters
sns.pairplot(data_viz, hue='Cluster', palette='tab10')
plt.suptitle("DBSCAN Clustering", y=1.01)
plt.show()
# Out:
# Cluster
#  0     1807
# -1     1140
#  5      443
#  4      284
#  1      189
#  2       46
#  16      11
#  20       9
#  8        7
#  3        7
#  17       7
#  18       6
#  7        5
#  13       5
#  6        4
#  9        4
#  12       4
#  14       4
#  15       4
#  21       4
#  10       3
#  19       3
#  11       3
# Name: count, dtype: int64
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
